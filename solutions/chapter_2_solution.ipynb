# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('2.2USArrests.csv')

# %%
#do the following: 
#1 - Address all missing values
#2 - Look for outliers and "smooth" noisy data
#3 - Prepare the dataset by converting urban population into categories
#small = < 50%, medium = <60%, large < 70%, extra large > 70% and above

# %%
df.head(2)
# Out:
#   Unnamed: 0  Murder  Assault  UrbanPop
# 0    Alabama    13.2    236.0        58
# 1     Alaska    10.0    263.0        48

# %%
#1 - Address all missing values
#count the nans
df.isnull().sum()
# Out:
# Unnamed: 0    0
# Murder        0
# Assault       1
# UrbanPop      0
# dtype: int64

# %%
#find nans - there is a 'True' value in row index 9 in the assault column
df.isnull()
# Out:
#     Unnamed: 0  Murder  Assault  UrbanPop
# 0        False   False    False     False
# 1        False   False    False     False
# 2        False   False    False     False
# 3        False   False    False     False
# 4        False   False    False     False
# 5        False   False    False     False
# 6        False   False    False     False
# 7        False   False    False     False
# 8        False   False    False     False
# 9        False   False     True     False
# 10       False   False    False     False
# 11       False   False    False     False
# 12       False   False    False     False
# 13       False   False    False     False
# 14       False   False    False     False
# 15       False   False    False     False
# 16       False   False    False     False
# 17       False   False    False     False
# 18       False   False    False     False
# 19       False   False    False     False
# 20       False   False    False     False
# ...

# %%
#fill nan with median
#df['Assault'] = df['Assault'].fillna(0)
df['Assault'] = df['Assault'].fillna(df['Assault'].median())

# %%
df
# Out:
#         Unnamed: 0  Murder  Assault  UrbanPop
# 0          Alabama    13.2    236.0        58
# 1           Alaska    10.0    263.0        48
# 2          Arizona     8.1    294.0        80
# 3         Arkansas     8.8    190.0        50
# 4       California     9.0    276.0        91
# 5         Colorado     7.9    204.0        78
# 6      Connecticut     3.3    110.0        77
# 7         Delaware     5.9    238.0        72
# 8          Florida    15.4    335.0        80
# 9          Georgia    17.4    159.0        60
# 10          Hawaii     5.3     46.0        83
# 11           Idaho     2.6    120.0        54
# 12        Illinois    10.4    249.0        83
# 13         Indiana     7.2    113.0        65
# 14            Iowa     2.2     56.0       570
# 15          Kansas     6.0    115.0        66
# 16        Kentucky     9.7    109.0        52
# 17       Louisiana    15.4    249.0        66
# 18           Maine     2.1     83.0        51
# ...

# %%
#2 - Look for outliers and "smooth" noisy data
#find outliers
df.describe()
# Out:
#          Murder     Assault   UrbanPop
# count  50.00000   50.000000   50.00000
# mean    7.78800  181.720000   74.20000
# std     4.35551  129.576554   73.40828
# min     0.80000   45.000000    6.00000
# 25%     4.07500  109.000000   53.25000
# 50%     7.25000  159.000000   66.00000
# 75%    11.25000  249.000000   77.75000
# max    17.40000  879.000000  570.00000

# %%
#the max value for 'Assault' is an outlier - let's replace it with the median
df['Assault'].max()
# Out:
# 879.0

# %%
#it exists in row index 39
df['Assault'].idxmax()
# Out:
# 39

# %%
df.iloc[39]
# Out:
# Unnamed: 0    South Carolina
# Murder                  14.4
# Assault                879.0
# UrbanPop                  48
# Name: 39, dtype: object

# %%
df['Assault'].median()
# Out:
# 159.0

# %%
# median = df.loc[df['Assault']==879.0, 'Assault'].median()
# df.loc[df.Assault > 75, 'Age'] = np.nan
# df.fillna(median,inplace=True)

# %%
median = df['Assault'].median()

# %%
df['Assault'].replace(879.0, median, inplace=True)

# %%
df.iloc[39]
# Out:
# Unnamed: 0    South Carolina
# Murder                  14.4
# Assault                159.0
# UrbanPop                  48
# Name: 39, dtype: object

# %%
#create an urban population cateogory
df.head()
# Out:
#    Unnamed: 0  Murder  Assault  UrbanPop
# 0     Alabama    13.2    236.0        58
# 1      Alaska    10.0    263.0        48
# 2     Arizona     8.1    294.0        80
# 3    Arkansas     8.8    190.0        50
# 4  California     9.0    276.0        91

# %%
print(df.dtypes)
# Out:
# Unnamed: 0     object
# Murder        float64
# Assault       float64
# UrbanPop        int64
# dtype: object

# %%
#3 - Prepare the dataset by converting urban population into categories
#small = < 50%, medium = <60%, large < 70%, extra large > 70% and above
bins = [0, 50, 60, 70, 100]
names = ['Small', 'Medium', 'Large', 'Extra Large']
df['UrbanPop Categories'] = pd.cut(df['UrbanPop'], bins, labels=names)

# %%
df.head()
# Out:
#    Unnamed: 0  Murder  Assault  UrbanPop UrbanPop Categories
# 0     Alabama    13.2    236.0        58              Medium
# 1      Alaska    10.0    263.0        48               Small
# 2     Arizona     8.1    294.0        80         Extra Large
# 3    Arkansas     8.8    190.0        50               Small
# 4  California     9.0    276.0        91         Extra Large
